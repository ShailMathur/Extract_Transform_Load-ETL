# %%
# import dependencies
import pandas as pd
from sqlalchemy import create_engine
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import psycopg2 as lily
import string

# %%
# Files to Load 
alldata_path = "Resources/alldata.csv"
datascientist_path = "Resources/dataScientist.csv"

# %%
# create the dataframe 
alldata_df = pd.read_csv(alldata_path)
alldata_df
# Out:
#                                                position  \
# 0                                  Development Director
# 1     An Ostentatiously-Excitable Principal Research...
# 2                                        Data Scientist
# 3                                          Data Analyst
# 4     Assistant Professor -TT - Signal Processing & ...
# ...                                                 ...
# 6959          Data Developer / Machine Learning Analyst
# 6960                                        Scientist I
# 6961                                   Intern Scientist
# 6962                    Senior Data & Applied Scientist
# 6963            Principal Data Scientist, Deep Learning
#
#                                company  \
# 0                              ALS TDI
# 1                   The Hexagon Lavish
# 2                       Xpert Staffing
# 3                       Operation HOPE
# 4                     Emory University
# ...                                ...
# 6959                            NetApp
# 6960  Pharmacyclics, an Abbvie Company
# 6961                          Oath Inc
# 6962                         Microsoft
# 6963                           Comcast
#
#                                             description  reviews  \
# 0     Development Director\nALS Therapy Development ...      NaN
# 1     Job Description\n\n"The road that leads to acc...      NaN
# 2     Growing company located in the Atlanta, GA are...      NaN
# 3     DEPARTMENT: Program OperationsPOSITION LOCATIO...     44.0
# 4     DESCRIPTION\nThe Emory University Department o...    550.0
# ...                                                 ...      ...
# 6959  Are you data-driven? We at NetApp believe in t...    574.0
# 6960  Pharmacyclics is committed to the development ...     26.0
# 6961  Oath, a subsidiary of Verizon, is a values-led...      5.0
# 6962  We are the Bing Core Relevance team responsibl...   4618.0
# 6963  Comcast’s Technology &amp; Product organizatio...  11610.0
#
#                  location
# 0      Atlanta, GA 30301
# 1             Atlanta, GA
# 2             Atlanta, GA
# 3      Atlanta, GA 30303
# 4             Atlanta, GA
# ...                   ...
# 6959        Sunnyvale, CA
# 6960        Sunnyvale, CA
# 6961        Sunnyvale, CA
# 6962        Sunnyvale, CA
# 6963  Sunnyvale, CA 94089
#
# [6964 rows x 5 columns]

# %%
# import the dataset
datascientist_df = pd.read_csv(datascientist_path)
datascientist_df
# Out:
#       Unnamed: 0  index                                          Job Title  \
# 0              0      0                              Senior Data Scientist
# 1              1      1                  Data Scientist, Product Analytics
# 2              2      2                               Data Science Manager
# 3              3      3                                       Data Analyst
# 4              4      4                             Director, Data Science
# ...          ...    ...                                                ...
# 3904        3904   4375                                  AWS Data Engineer
# 3905        3905   4376                              Data Analyst â Junior
# 3906        3906   4377                   Security Analytics Data Engineer
# 3907        3907   4378                   Security Analytics Data Engineer
# 3908        3908   4379  Patient Safety Physician or Safety Scientist -...
#
#                    Salary Estimate  \
# 0     $111K-$181K (Glassdoor est.)
# 1     $111K-$181K (Glassdoor est.)
# 2     $111K-$181K (Glassdoor est.)
# 3     $111K-$181K (Glassdoor est.)
# 4     $111K-$181K (Glassdoor est.)
# ...                            ...
# 3904   $55K-$112K (Glassdoor est.)
# 3905   $55K-$112K (Glassdoor est.)
# 3906   $55K-$112K (Glassdoor est.)
# 3907   $55K-$112K (Glassdoor est.)
# 3908   $55K-$112K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 0     ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5
# 1     At Noom, we use scientifically proven methods ...     4.5
# 2     Decode_M\n\nhttps://www.decode-m.com/\n\nData ...    -1.0
# 3     Sapphire Digital seeks a dynamic and driven mi...     3.4
# 4     Director, Data Science - (200537)\nDescription...     3.4
# ...                                                 ...     ...
# 3904  About Us\n\nTachyon Technologies is a Digital ...     4.4
# 3905  Job description\nInterpret data, analyze resul...     5.0
# 3906  Job DescriptionThe Security Analytics Data Eng...     3.8
# 3907  The Security Analytics Data Engineer will inte...     4.0
# 3908  Help us transform patients' lives.\nAt UCB, we...     3.7
#
#                                Company Name       Location      Headquarters  \
# 0                               Hopper\n3.5   New York, NY  Montreal, Canada
# 1                              Noom US\n4.5   New York, NY      New York, NY
# 2                                  Decode_M   New York, NY      New York, NY
# 3                     Sapphire Digital\n3.4  Lyndhurst, NJ     Lyndhurst, NJ
# 4           United Entertainment Group\n3.4   New York, NY      New York, NY
# ...                                     ...            ...               ...
# 3904              Tachyon Technologies\n4.4     Dublin, OH        Irving, TX
# 3905  Staffigo Technical Services, LLC\n5.0   Columbus, OH     Woodridge, IL
# 3906                    PDS Tech, Inc.\n3.8     Dublin, OH        Irving, TX
# 3907        Data Resource Technologies\n4.0     Dublin, OH         Omaha, NE
# 3908                               UCB\n3.7     Slough, OH  Brussel, Belgium
#
#                          Size  Founded  Type of ownership  \
# 0       501 to 1000 employees     2007  Company - Private
# 1      1001 to 5000 employees     2008  Company - Private
# 2           1 to 50 employees       -1            Unknown
# 3        201 to 500 employees     2019  Company - Private
# 4         51 to 200 employees     2007  Company - Private
# ...                       ...      ...                ...
# 3904     201 to 500 employees     2011  Company - Private
# 3905      51 to 200 employees     2008  Company - Private
# 3906  5001 to 10000 employees     1977  Company - Private
# 3907        1 to 50 employees       -1  Company - Private
# 3908  5001 to 10000 employees       -1   Company - Public
#
#                        Industry                     Sector  \
# 0               Travel Agencies           Travel & Tourism
# 1     Health, Beauty, & Fitness          Consumer Services
# 2                            -1                         -1
# 3                      Internet     Information Technology
# 4       Advertising & Marketing          Business Services
# ...                         ...                        ...
# 3904                IT Services     Information Technology
# 3905                IT Services     Information Technology
# 3906     Staffing & Outsourcing          Business Services
# 3907                 Accounting         Accounting & Legal
# 3908  Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
#
#                          Revenue               Competitors Easy Apply
# 0       Unknown / Non-Applicable                        -1         -1
# 1       Unknown / Non-Applicable                        -1         -1
# 2       Unknown / Non-Applicable                        -1       True
# 3       Unknown / Non-Applicable      Zocdoc, Healthgrades         -1
# 4       Unknown / Non-Applicable  BBDO, Grey Group, Droga5         -1
# ...                          ...                       ...        ...
# 3904    $10 to $25 million (USD)                        -1         -1
# 3905   $50 to $100 million (USD)                        -1         -1
# 3906  $100 to $500 million (USD)                        -1         -1
# 3907  Less than $1 million (USD)                        -1         -1
# 3908      $2 to $5 billion (USD)                    AbbVie         -1
#
# [3909 rows x 17 columns]

# %%
# delete extra columns in dataScientist csv
datascientist_df .drop(['Unnamed: 0' , 'Job Description', 'Headquarters', 'Size', 'Founded', 'Type of ownership', 'Revenue', 'Sector','Competitors', 'Easy Apply'], axis=1, inplace=True)
datascientist_df
# Out:
#       index                                          Job Title  \
# 0         0                              Senior Data Scientist
# 1         1                  Data Scientist, Product Analytics
# 2         2                               Data Science Manager
# 3         3                                       Data Analyst
# 4         4                             Director, Data Science
# ...     ...                                                ...
# 3904   4375                                  AWS Data Engineer
# 3905   4376                              Data Analyst â Junior
# 3906   4377                   Security Analytics Data Engineer
# 3907   4378                   Security Analytics Data Engineer
# 3908   4379  Patient Safety Physician or Safety Scientist -...
#
#                    Salary Estimate  Rating  \
# 0     $111K-$181K (Glassdoor est.)     3.5
# 1     $111K-$181K (Glassdoor est.)     4.5
# 2     $111K-$181K (Glassdoor est.)    -1.0
# 3     $111K-$181K (Glassdoor est.)     3.4
# 4     $111K-$181K (Glassdoor est.)     3.4
# ...                            ...     ...
# 3904   $55K-$112K (Glassdoor est.)     4.4
# 3905   $55K-$112K (Glassdoor est.)     5.0
# 3906   $55K-$112K (Glassdoor est.)     3.8
# 3907   $55K-$112K (Glassdoor est.)     4.0
# 3908   $55K-$112K (Glassdoor est.)     3.7
#
#                                Company Name       Location  \
# 0                               Hopper\n3.5   New York, NY
# 1                              Noom US\n4.5   New York, NY
# 2                                  Decode_M   New York, NY
# 3                     Sapphire Digital\n3.4  Lyndhurst, NJ
# 4           United Entertainment Group\n3.4   New York, NY
# ...                                     ...            ...
# 3904              Tachyon Technologies\n4.4     Dublin, OH
# 3905  Staffigo Technical Services, LLC\n5.0   Columbus, OH
# 3906                    PDS Tech, Inc.\n3.8     Dublin, OH
# 3907        Data Resource Technologies\n4.0     Dublin, OH
# 3908                               UCB\n3.7     Slough, OH
#
#                        Industry
# 0               Travel Agencies
# 1     Health, Beauty, & Fitness
# 2                            -1
# 3                      Internet
# 4       Advertising & Marketing
# ...                         ...
# 3904                IT Services
# 3905                IT Services
# 3906     Staffing & Outsourcing
# 3907                 Accounting
# 3908  Biotech & Pharmaceuticals
#
# [3909 rows x 7 columns]

# %%
# delete extra columns in alldata csv
alldata_df .drop(['description', 'reviews'], axis=1, inplace=True)
alldata_df
# Out:
#                                                position  \
# 0                                  Development Director
# 1     An Ostentatiously-Excitable Principal Research...
# 2                                        Data Scientist
# 3                                          Data Analyst
# 4     Assistant Professor -TT - Signal Processing & ...
# ...                                                 ...
# 6959          Data Developer / Machine Learning Analyst
# 6960                                        Scientist I
# 6961                                   Intern Scientist
# 6962                    Senior Data & Applied Scientist
# 6963            Principal Data Scientist, Deep Learning
#
#                                company             location
# 0                              ALS TDI   Atlanta, GA 30301
# 1                   The Hexagon Lavish          Atlanta, GA
# 2                       Xpert Staffing          Atlanta, GA
# 3                       Operation HOPE   Atlanta, GA 30303
# 4                     Emory University          Atlanta, GA
# ...                                ...                  ...
# 6959                            NetApp        Sunnyvale, CA
# 6960  Pharmacyclics, an Abbvie Company        Sunnyvale, CA
# 6961                          Oath Inc        Sunnyvale, CA
# 6962                         Microsoft        Sunnyvale, CA
# 6963                           Comcast  Sunnyvale, CA 94089
#
# [6964 rows x 3 columns]

# %%
# drop all rows with missing information in alldata
alldata_df = alldata_df.dropna(how='any')

# %%
# verify dropped rows in alldata
alldata_df.count()
# Out:
# position    6953
# company     6953
# location    6953
# dtype: int64

# %%
# drop all rows with missing information in DataScientist csv
datascientist_df = datascientist_df.dropna(how='any')

# %%
# verify dropped rows in datascientist csv
datascientist_df.count()
# Out:
# index              3909
# Job Title          3909
# Salary Estimate    3909
# Rating             3909
# Company Name       3909
# Location           3909
# Industry           3909
# dtype: int64

# %%
# rename the column names in alldata csv
alldata_df.columns=["Position", "Company", "Location"]
alldata_df
# Out:
#                                                Position  \
# 0                                  Development Director
# 1     An Ostentatiously-Excitable Principal Research...
# 2                                        Data Scientist
# 3                                          Data Analyst
# 4     Assistant Professor -TT - Signal Processing & ...
# ...                                                 ...
# 6959          Data Developer / Machine Learning Analyst
# 6960                                        Scientist I
# 6961                                   Intern Scientist
# 6962                    Senior Data & Applied Scientist
# 6963            Principal Data Scientist, Deep Learning
#
#                                Company             Location
# 0                              ALS TDI   Atlanta, GA 30301
# 1                   The Hexagon Lavish          Atlanta, GA
# 2                       Xpert Staffing          Atlanta, GA
# 3                       Operation HOPE   Atlanta, GA 30303
# 4                     Emory University          Atlanta, GA
# ...                                ...                  ...
# 6959                            NetApp        Sunnyvale, CA
# 6960  Pharmacyclics, an Abbvie Company        Sunnyvale, CA
# 6961                          Oath Inc        Sunnyvale, CA
# 6962                         Microsoft        Sunnyvale, CA
# 6963                           Comcast  Sunnyvale, CA 94089
#
# [6953 rows x 3 columns]

# %%
# rename the column names in datascientist csv
datascientist_df.columns=["Index" , "Position", "Salary Estimate" , "Rating" , "Company", "Location" , "Industry"]
datascientist_df
# Out:
#       Index                                           Position  \
# 0         0                              Senior Data Scientist
# 1         1                  Data Scientist, Product Analytics
# 2         2                               Data Science Manager
# 3         3                                       Data Analyst
# 4         4                             Director, Data Science
# ...     ...                                                ...
# 3904   4375                                  AWS Data Engineer
# 3905   4376                              Data Analyst â Junior
# 3906   4377                   Security Analytics Data Engineer
# 3907   4378                   Security Analytics Data Engineer
# 3908   4379  Patient Safety Physician or Safety Scientist -...
#
#                    Salary Estimate  Rating  \
# 0     $111K-$181K (Glassdoor est.)     3.5
# 1     $111K-$181K (Glassdoor est.)     4.5
# 2     $111K-$181K (Glassdoor est.)    -1.0
# 3     $111K-$181K (Glassdoor est.)     3.4
# 4     $111K-$181K (Glassdoor est.)     3.4
# ...                            ...     ...
# 3904   $55K-$112K (Glassdoor est.)     4.4
# 3905   $55K-$112K (Glassdoor est.)     5.0
# 3906   $55K-$112K (Glassdoor est.)     3.8
# 3907   $55K-$112K (Glassdoor est.)     4.0
# 3908   $55K-$112K (Glassdoor est.)     3.7
#
#                                     Company       Location  \
# 0                               Hopper\n3.5   New York, NY
# 1                              Noom US\n4.5   New York, NY
# 2                                  Decode_M   New York, NY
# 3                     Sapphire Digital\n3.4  Lyndhurst, NJ
# 4           United Entertainment Group\n3.4   New York, NY
# ...                                     ...            ...
# 3904              Tachyon Technologies\n4.4     Dublin, OH
# 3905  Staffigo Technical Services, LLC\n5.0   Columbus, OH
# 3906                    PDS Tech, Inc.\n3.8     Dublin, OH
# 3907        Data Resource Technologies\n4.0     Dublin, OH
# 3908                               UCB\n3.7     Slough, OH
#
#                        Industry
# 0               Travel Agencies
# 1     Health, Beauty, & Fitness
# 2                            -1
# 3                      Internet
# 4       Advertising & Marketing
# ...                         ...
# 3904                IT Services
# 3905                IT Services
# 3906     Staffing & Outsourcing
# 3907                 Accounting
# 3908  Biotech & Pharmaceuticals
#
# [3909 rows x 7 columns]

# %%
# clean the alldata.csv based on following Position

alldata_new_df = alldata_df.loc[(alldata_df["Position"].str.contains("Scientist")) | 
                                (alldata_df["Position"].str.contains("Analyst")) |
                                (alldata_df["Position"].str.contains("Engineer")) |
                                (alldata_df["Position"].str.contains("Research Scientist")) |
                                (alldata_df["Position"].str.contains("System Engineer")) |
                                (alldata_df["Position"].str.contains("Web Developer")) |
                                (alldata_df["Position"].str.contains("Amazon AI- Applied Scientist"))]

alldata_new_df
# Out:
#                                                Position  \
# 1     An Ostentatiously-Excitable Principal Research...
# 2                                        Data Scientist
# 3                                          Data Analyst
# 5                           Manager of Data Engineering
# 7     Junior to Mid-level Engineer, Geologist or Env...
# ...                                                 ...
# 6959          Data Developer / Machine Learning Analyst
# 6960                                        Scientist I
# 6961                                   Intern Scientist
# 6962                    Senior Data & Applied Scientist
# 6963            Principal Data Scientist, Deep Learning
#
#                                Company             Location
# 1                   The Hexagon Lavish          Atlanta, GA
# 2                       Xpert Staffing          Atlanta, GA
# 3                       Operation HOPE   Atlanta, GA 30303
# 5                   McKinsey & Company   Atlanta, GA 30318
# 7                                 Wood          Atlanta, GA
# ...                                ...                  ...
# 6959                            NetApp        Sunnyvale, CA
# 6960  Pharmacyclics, an Abbvie Company        Sunnyvale, CA
# 6961                          Oath Inc        Sunnyvale, CA
# 6962                         Microsoft        Sunnyvale, CA
# 6963                           Comcast  Sunnyvale, CA 94089
#
# [4634 rows x 3 columns]

# %%
# output clean dataframe to csv for alldata.csv

alldata = "Resources/alldata(clean).csv"
alldata_new_df.to_csv(alldata,index=False)

# %%
# output clean dataframe to csv for datascientist.csv

datascientist = "Resources/datascientist(clean).csv"
datascientist_df.to_csv(datascientist,index=False)

# %%
# merge after invidual csv clean for multiple coloumns
ds_alldata=alldata_new_df.merge(datascientist_df,on=["Position","Location"])

# %%
#connect to database
def execute_sql_statement(sqltext):
    conn=lily.connect( host="localhost", database="ELT_project", user="postgres", password="Abcd1234")
#cursor is an object to put watever you want
    cursor=conn.cursor()
#xecute() method
    cursor.execute(sqltext)
    conn.commit()
#Closing the connection
    conn.close()

#from config import sqldb_connect
#engine = create_engine(sqldb_connect)

# %%
#Dropping all tables gathered 
execute_sql_statement("DROP TABLE IF EXISTS alldata,datascientist,Company,Location,Industry,Position CASCADE;")

# %%
#database tables
#Creating table as per requirement 
sql ='''CREATE TABLE Company( ID INT GENERATED ALWAYS AS IDENTITY, name VARCHAR(255) NOT NULL, PRIMARY KEY(ID))''' 
execute_sql_statement(sql)
print("Table created successfully........") 
#Closing the connection conn.close()
# Out:
# Table created successfully........

# %%
#system diagram

# %%
#Creating table as per requirement 
sql ='''CREATE TABLE Position( ID INT GENERATED ALWAYS AS IDENTITY, name VARCHAR(255) NOT NULL, PRIMARY KEY(ID))''' 
execute_sql_statement(sql)
print("Table created successfully........")
# Out:
# Table created successfully........

# %%
#Creating table as per requirement 
sql ='''CREATE TABLE Location( ID INT GENERATED ALWAYS AS IDENTITY, name VARCHAR(255) NOT NULL, PRIMARY KEY(ID) )''' 
execute_sql_statement(sql)
print("Table created successfully........")
# Out:
# Table created successfully........

# %%
#Creating for all data
#Creating table as per requirement 
sql ='''CREATE TABLE alldata( ID INT GENERATED ALWAYS AS IDENTITY,
PositionID INT, 
CompanyID INT, 
LocationID INT, 
PRIMARY KEY(ID),
CONSTRAINT fk_Pos_id FOREIGN KEY(PositionID) REFERENCES Position(ID),
CONSTRAINT fk_Comp_id FOREIGN KEY(CompanyID) REFERENCES Company(ID),
CONSTRAINT fk_Loc_id FOREIGN KEY(LocationID) REFERENCES Location(ID))'''
execute_sql_statement(sql)
print("Table created successfully........")
# Out:
# Table created successfully........

# %%
#Tables for Data scientist 
#Creating table as per requirement 
sql ='''CREATE TABLE Industry( ID INT GENERATED ALWAYS AS IDENTITY, name VARCHAR(255) NOT NULL, PRIMARY KEY(ID) )''' 
execute_sql_statement(sql)
print("Table created successfully........")
# Out:
# Table created successfully........

# %%
#Creating table as per requirement 
sql ='''CREATE TABLE datascientist(ID INT GENERATED ALWAYS AS IDENTITY, PositionID INT, CompanyID INT, LocationID INT, IndustryID INT, Rating decimal, Salary_estimate VARCHAR(255), PRIMARY KEY(ID), CONSTRAINT fk_pos_1 FOREIGN KEY(PositionID) REFERENCES Position(ID) ON DELETE CASCADE, CONSTRAINT fk_comp_1 FOREIGN KEY(CompanyID) REFERENCES Company(ID) ON DELETE CASCADE, CONSTRAINT fk_loc_1 FOREIGN KEY(LocationID) REFERENCES Location(ID) ON DELETE CASCADE, CONSTRAINT fk_indus FOREIGN KEY(IndustryID) REFERENCES Industry(ID) ON DELETE CASCADE)''' 
execute_sql_statement(sql)
print("Table created successfully........")
# Out:
# Table created successfully........

# %%
#Insert Data
#Create Engine and connection to Database
engine = create_engine('postgresql://postgres:Abcd1234@localhost:5432/ELT_project')

# %%
alldata_df.to_sql("all_data_df",engine,if_exists="replace")

# %%
datascientist_df.to_sql("datascientist_df",engine,if_exists="replace")

# %%
#Normalizing data
df_position=pd.DataFrame(alldata_df.Position.unique())

# %%
df_position.columns=["name"]

# %%
df_position.to_sql("position",engine,if_exists="append",index=False)

# %%
df_Location=pd.DataFrame(alldata_df.Location.unique())
df_Location.columns=["name"]
df_Location.to_sql("location",engine,if_exists="append",index=False)

# %%
df_Industry=pd.DataFrame(datascientist_df.Industry.unique())
df_Industry.columns=["name"]
df_Industry.to_sql("industry",engine,if_exists="append",index=False)

# %%
df_Company=pd.DataFrame(alldata_new_df.Company.unique())
df_Company.columns=["name"]
df_Company.to_sql("company",engine,if_exists="append",index=False)

# %%
#Create a function to creat a sql for PositionID,companyID and LocationID
def insert_for_alldata(pos_name,loc_name,comp_name):
    sql='''insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from position p,location l, company c where p.name=\''''+pos_name+'''\' and l.name=\''''+loc_name+'''\' and c.name=\''''+comp_name+'\''
    print(sql)
    execute_sql_statement(sql)
    return "success"

# %%
alldata_df["inserted"]=alldata_df.apply(lambda row: insert_for_alldata(row['Position'].translate(str.maketrans('', '', string.punctuation)), row['Location'].translate(str.maketrans('', '', string.punctuation)),row['Company'].translate(str.maketrans('', '', string.punctuation))) , axis =1)
# Out:
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Development Director' and l.name='Atlanta GA 30301 ' and c.name='ALS TDI'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='An OstentatiouslyExcitable Principal Research Assistant to Chief Scientist' and l.name='Atlanta GA' and c.name='The Hexagon Lavish'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Atlanta GA' and c.name='Xpert Staffing'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Analyst' and l.name='Atlanta GA 30303 ' and c.name='Operation HOPE'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Assistant Professor TT  Signal Processing  Machine Learning' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Manager of Data Engineering' and l.name='Atlanta GA 30318 ' and c.name='McKinsey  Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Product Specialist  Periscope New Ventures' and l.name='Atlanta GA 30318 ' and c.name='McKinsey  Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Junior to Midlevel Engineer Geologist or Environmental Scientist' and l.name='Atlanta GA' and c.name='Wood'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Analyst  CIB Credit Research' and l.name='Atlanta GA' and c.name='SunTrust'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Associate  Cognitive Data Scientist Natural Language Processing' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='STATISTICAL FORECAST ANALYST' and l.name='Atlanta GA' and c.name='The Home Depot'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Health Scientist IIICPTS' and l.name='Atlanta GA' and c.name='Chenega Corporation'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Associate Data Scientist' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Assistant Scientist AR SOM' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Business Intelligence Data Science Analyst  Supply Chain' and l.name='Atlanta GA' and c.name='Newell Brands'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Atlanta GA' and c.name='Cotiviti'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Structural EngineerTransmission  Distribution' and l.name='Atlanta GA 30309 ' and c.name='Burns  McDonnell'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Mobile Developer iOSAndroid' and l.name='Atlanta GA 30338' and c.name='Perficient'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Atlanta GA' and c.name='Relus Cloud'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Atlanta GA' and c.name='Inspire Brands'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Electrical Engineer' and l.name='Atlanta GA 30309 ' and c.name='Burns  McDonnell'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sr Manager Full Stack Development KPMG Tax Ignition' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Atlanta GA 30309 ' and c.name='Norfolk Southern Corp'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='DATA SCIENTIST  Supply Chain' and l.name='Atlanta GA' and c.name='The Home Depot'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist Keying  Linking' and l.name='Atlanta GA' and c.name='Equifax'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Atlanta GA' and c.name='AirSage'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist 1 – AP Forensics Team' and l.name='Atlanta GA' and c.name='The Home Depot'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist  ICL' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist Online' and l.name='Atlanta GA' and c.name='The Home Depot'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist  CONSULTANT Level  ORLANDO FLORIDA  We will help Relocate' and l.name='Atlanta GA' and c.name='Capgemini'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Data Scientist' and l.name='Atlanta GA' and c.name='Catalina Marketing'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Business Intelligence Data Scientist  Supply Chain' and l.name='Atlanta GA' and c.name='Newell Brands'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Entry LevelJuniorLevel Scientist' and l.name='Atlanta GA' and c.name='Kleinfelder Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Scientist  Data Analysis' and l.name='Atlanta GA' and c.name='AMERICAN CANCER SOCIETY'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Atlanta GA' and c.name='SalesLoft'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Atlanta GA 30329' and c.name='McKesson'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Atlanta GA 30328' and c.name='The Intersect Group'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Health Scientist' and l.name='Atlanta GA' and c.name='Centers for Disease Control and Prevention'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Atlanta GA' and c.name='OM Partners'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='DATA SCIENTIST  SPACE OPTIMIZATION' and l.name='Atlanta GA' and c.name='The Home Depot'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Science Specialist  Periscope New Ventures' and l.name='Atlanta GA 30318 ' and c.name='McKinsey  Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Data Scientist' and l.name='Atlanta GA' and c.name='Cotiviti'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Manager  Data Scientist  Orlando' and l.name='Atlanta GA' and c.name='Capgemini'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Scientist II' and l.name='Atlanta GA 30301 ' and c.name='The CocaCola Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Lead Data Scientist' and l.name='Atlanta GA 30309 ' and c.name='Norfolk Southern Corp'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Data Scientist' and l.name='Atlanta GA 30309 ' and c.name='Norfolk Southern Corp'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist  Consultant Level  Orlando Florida  we will assist with relocation' and l.name='Atlanta GA' and c.name='Capgemini'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Flight Safety Data Analysis Fall CoOp' and l.name='Atlanta GA' and c.name='Delta Air Lines'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Chief Deep Learning Scientist' and l.name='Atlanta GA' and c.name='YIWEI Medical Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Supervisory Health Scientist' and l.name='Atlanta GA' and c.name='Centers for Disease Control and Prevention'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Manager  Cognitive Data Scientist Natural Language Processing' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Director Data Scientist' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='VP Data Scientist Atlanta GA Charlotte NC' and l.name='Atlanta GA' and c.name='Bank of America Merchant Services'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Statistical Analyst' and l.name='Atlanta GA' and c.name='Hawkins Diagnostics'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='VP Data Analytics' and l.name='Atlanta GA' and c.name='TCGplayer'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Lead Decision Scientist' and l.name='Atlanta GA 30313 ' and c.name='Moxie Interactive Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Scientist I  Sensory Panel Leader' and l.name='Atlanta GA 30301 ' and c.name='The CocaCola Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist or Data Scientist Lead PS10268' and l.name='Atlanta GA 30301 ' and c.name='Anthem Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Lead Decision Scientist' and l.name='Atlanta GA' and c.name='Moxie'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Cyber Security Data Scientist' and l.name='Atlanta GA 30306 ' and c.name='Bank of America'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Scientist IIEcologist II' and l.name='Atlanta GA 30327 ' and c.name='HNTB Corporation'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Engineer' and l.name='Atlanta GA' and c.name='Gallup'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Manager Data Scientist' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Machine Learning  Artificial Intelligence Research Scientist' and l.name='Atlanta GA 30338' and c.name='Symantec'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Statistical Quantitative Analyst' and l.name='Atlanta GA' and c.name='SunTrust'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Research Scientist' and l.name='Atlanta GA' and c.name='MacDermid Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Environmental Scientist' and l.name='Atlanta GA' and c.name='Tetra Tech'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Scientist Asst Bioinformatics' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Research Analyst' and l.name='Atlanta GA' and c.name='Evident'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Scientist Asst AR SOM' and l.name='Atlanta GA 30322' and c.name='Emory Healthcare'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Analyst Research' and l.name='Atlanta GA 30319' and c.name='Turner'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Director NLP Data Scientist' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Information Technology Specialist' and l.name='Atlanta GA' and c.name='Centers for Disease Control and Prevention'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Quantitative Analyst' and l.name='Atlanta GA 30342 ' and c.name='GreenSky'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='DATA ANALYST SUPPLY CHAIN' and l.name='Atlanta GA' and c.name='The Home Depot'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Scientist Asst AR SOM' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Health Communications Specialist' and l.name='Atlanta GA' and c.name='Eagle Medical Services'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Associate Data Scientist NLPAI' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Engineer  GC Insights New Ventures' and l.name='Atlanta GA 30318 ' and c.name='McKinsey  Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Technical Evangelist – Database Analytics and Machine Learning' and l.name='Atlanta GA' and c.name='Amazoncom'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sr Scientist II Analytical Science' and l.name='Atlanta GA 30301 ' and c.name='The CocaCola Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Director of Data Science' and l.name='Atlanta GA' and c.name='Prestige Staffing'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='HIV Research Scientist' and l.name='Atlanta GA' and c.name='Eagle Medical Services'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='SI CoE IoT Data Modeling Architect' and l.name='Atlanta GA' and c.name='Xylem'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Research Scientist' and l.name='Atlanta GA' and c.name='PreVisor'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Azure Data Scientist Manager' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Associate Scientist SOM' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Engineer Scala' and l.name='Atlanta GA' and c.name='CapTech Consulting'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Director Financial Services  Data Scientist' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Regulatory Labeling Advertising and Promotion Scientist' and l.name='Atlanta GA' and c.name='UCB'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data  Analytics Developer' and l.name='Atlanta GA' and c.name='SunTrust'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Product Development Scientist' and l.name='Atlanta GA 30301 ' and c.name='The CocaCola Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Research Scientist I' and l.name='Atlanta GA' and c.name='Georgia State University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist  Senior Consultant  Orlando Florida' and l.name='Atlanta GA' and c.name='Capgemini'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Lead R  D EngineerScientist' and l.name='Atlanta GA 30308 ' and c.name='Honeywell'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Quantitative Finance Analyst' and l.name='Atlanta GA 30308 ' and c.name='Bank of America'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Advertiser Research Analyst' and l.name='Atlanta GA' and c.name='Cox Media Group'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Manager Data Scientist MLNLP  Financial Services' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Science Instructor' and l.name='Atlanta GA' and c.name='General Assembly'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Research Informatics Analyst' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Enterprise Data Analyst  Data Engineer' and l.name='Atlanta GA' and c.name='Novelis'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Supply Chain Data Science Consultant' and l.name='Atlanta GA' and c.name='Accenture'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Public Health Communications Specialist' and l.name='Atlanta GA 30328' and c.name='2M Research Services'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Communications Specialist' and l.name='Atlanta GA 30318 ' and c.name='Loyal'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='2018  Health Research Analyst 2  New' and l.name='Atlanta GA 30301 ' and c.name='Northrop Grumman'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Business Intelligence Engineer' and l.name='Atlanta GA' and c.name='Amazoncom'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Staff Research Scientist VII Informational Interpretation Researcher' and l.name='Atlanta GA' and c.name='The Hexagon Lavish'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Scientist Asst AR School Of Medicine SOM' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Entry Level Geologist Engineer or Environmental Scientist' and l.name='Atlanta GA' and c.name='Wood'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Regulatory Labeling Advertising and Promotion Scientist' and l.name='Atlanta GA' and c.name='UCB SA'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Quantitative Analyst' and l.name='Atlanta GA 30327 ' and c.name='Voya Financial'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Director Data Scientist  Financial ServicesInsurance' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Supervisory Epidemiologist' and l.name='Atlanta GA' and c.name='Centers for Disease Control and Prevention'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Quantitative Finance AnalystC Developer' and l.name='Atlanta GA 30308 ' and c.name='Bank of America'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Jr Microbiologist  CDC' and l.name='Atlanta GA' and c.name='G2S Corporation'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Azure Data Scientist Senior Associate' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Research Analyst' and l.name='Atlanta GA' and c.name='Epiq Systems Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Coding Research Analyst' and l.name='Atlanta GA' and c.name='Zelis Healthcare'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Science Manager Atlanta' and l.name='Atlanta GA' and c.name='Capgemini'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Quantitative Analyst' and l.name='Atlanta GA' and c.name='Intercontinental Exchange'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Visualization Software Engineer' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Business Intelligence Analyst People Analytics  Measurement' and l.name='Atlanta GA 30318 ' and c.name='McKinsey  Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Mid Data Scientist  Machine Learning' and l.name='Atlanta GA 30342 ' and c.name='Elev8 Hire Solutions'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Vendor Research Analyst' and l.name='Atlanta GA' and c.name='Northside Hospital'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Big Data SW Engineer' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Scientist Content Science' and l.name='Atlanta GA' and c.name='Pandora Media Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sponsored Research Financial Analyst' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Supply Chain Data Science Manager' and l.name='Atlanta GA' and c.name='Accenture'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Director HR Data and Insights' and l.name='Atlanta GA' and c.name='WestRock'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='BI Quantitative Analyst' and l.name='Atlanta GA 30341' and c.name='Childrens Healthcare of Atlanta'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Research Specialist' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Associate Product Designer' and l.name='Atlanta GA 30319' and c.name='IBM'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Ecologist' and l.name='Atlanta GA 30326 ' and c.name='VHB'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Tech Fall 2018 Intern  Machine Learning' and l.name='Atlanta GA 30319' and c.name='Turner'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='RD Innovation Engineer  Video AnalyticsMachine Learning' and l.name='Atlanta GA 30308 ' and c.name='Honeywell'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Lead Data Engineer' and l.name='Atlanta GA 30361 ' and c.name='ThoughtWorks'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Analytics Engineer  Big Data Engineer' and l.name='Atlanta GA' and c.name='UST Global Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Corporate Investment Quantitative Finance Analyst' and l.name='Atlanta GA 30308 ' and c.name='Bank of America'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Malware Analyst' and l.name='Atlanta GA' and c.name='ICF'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Principal Research Scientist I Informational Library Architect Extraordinaire' and l.name='Atlanta GA' and c.name='The Hexagon Lavish'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Market Research Analyst' and l.name='Atlanta GA' and c.name='SKIM'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Manager Statistical Modeling  Analytics' and l.name='Atlanta GA 30363 ' and c.name='Piedmont Healthcare'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Scientist Advertising' and l.name='Atlanta GA' and c.name='Pandora Media Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Junior Specialist  Periscope Advanced Insights Growth Mapping New Ventures' and l.name='Atlanta GA 30318 ' and c.name='McKinsey  Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Full Stack Developer' and l.name='Atlanta GA 30342 ' and c.name='GreenSky'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Associate Data ScientistStatistics  Financial Services' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Assistant Scientist  Metabolics Division Lead' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Data Engineer Next Big Sound' and l.name='Atlanta GA' and c.name='Pandora Media Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Market Research Analyst' and l.name='Atlanta GA' and c.name='ResMed'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Biomedical Engineering Faculty Position  Open Rank Asst or Assoc Professor' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Solutions Consultant' and l.name='Atlanta GA' and c.name='Oversight Systems'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Scientist Immunology' and l.name='Atlanta GA' and c.name='GeoVax Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Director Data Science PS6695' and l.name='Atlanta GA 30301 ' and c.name='Anthem Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='A VigorouslyCharged Scientific Programmer' and l.name='Atlanta GA' and c.name='The Hexagon Lavish'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Software Engineer' and l.name='Atlanta GA' and c.name='FraudScope'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sr Data Scientist – Market Research' and l.name='Atlanta GA' and c.name='Analytic Recruiting'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Director of Software' and l.name='Atlanta GA 30332 ' and c.name='Bionic Sciences Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Certifying Scientist  Quantitation Scientist' and l.name='Atlanta GA' and c.name='Lighthouse Lab Services'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Data Scientist' and l.name='Atlanta GA' and c.name='Smith Hanley Associates'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sr Manager  Data  Analytics' and l.name='Atlanta GA 30319' and c.name='General Electric'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Big Data Engineer mid to senior level' and l.name='Atlanta GA 30342 ' and c.name='GreenSky'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Atlanta GA 30326 ' and c.name='Xpect SVC LLC'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Science  Senior Consultant' and l.name='Atlanta GA' and c.name='Capgemini'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Adolescent Health Evaluation Specialist' and l.name='Atlanta GA' and c.name='ICF'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Windows Programmer  Software Engineer  IntermediateSenior ELSYS 7332' and l.name='Atlanta GA' and c.name='The Goal Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sr Data Engineer' and l.name='Atlanta GA' and c.name='Optomi'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Team Lead – Informatics Sensus USA Inc Atlanta Georgia' and l.name='Atlanta GA' and c.name='Xylem'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Electrical  Substation Design Engineer' and l.name='Atlanta GA 30309 ' and c.name='Burns  McDonnell'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Windows Programmer  Software Engineer Advanced Degree  ELSYS' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='ElectricalComputer Engineer  EOSL' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Windows Programmer  Software Engineer  Entry Intermediate ELSYS  7333' and l.name='Atlanta GA' and c.name='The Goal Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Principal Research Scientist' and l.name='Atlanta GA' and c.name='Headway Workforce Solutions'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Business Intelligence Analyst' and l.name='Atlanta GA' and c.name='The Home Depot'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Software Engineer Machine Learning' and l.name='Atlanta GA' and c.name='Pandora Media Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Scientist' and l.name='Atlanta GA' and c.name='RD Partners'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Staff CAD Technician' and l.name='Atlanta GA 30341' and c.name='Golder Associates'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Engineering Coop' and l.name='Atlanta GA 30341' and c.name='Golder Associates'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Associate Manager Agile Paid Media' and l.name='Atlanta GA' and c.name='The Home Depot'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Category Manager' and l.name='Atlanta GA' and c.name='JUUL Labs'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='FPGA Hardware Researcher  CIPHER' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Marketing Research Analyst' and l.name='Atlanta GA 30309 ' and c.name='HD Supply'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='RightofWay Acquisition Manager  Atlanta GA' and l.name='Atlanta GA' and c.name='Gresham Smith and Partners'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Associate Research Scientist' and l.name='Atlanta GA' and c.name='RD Partners'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='EntryLevel Electrical Engineer' and l.name='Atlanta GA 30309 ' and c.name='Burns  McDonnell'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Staff Software Engineer' and l.name='Atlanta GA 30319' and c.name='General Electric'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Principal Engineer' and l.name='Atlanta GA' and c.name='Cotiviti'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='DevOps Engineer  ELSYS' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Analyst Payments Study  GC Insights New Ventures' and l.name='Atlanta GA 30318 ' and c.name='McKinsey  Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Analyst  Multiclient Benchmarks GC Insights  New Ventures' and l.name='Atlanta GA 30318 ' and c.name='McKinsey  Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='BI  Analytics  Cloud Platform Operations Analyst' and l.name='Atlanta GA 30301 ' and c.name='The CocaCola Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sr Quantitative Finance AnalystC Developer' and l.name='Atlanta GA 30308 ' and c.name='Bank of America'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Business Analytics Consultant Sr' and l.name='Atlanta GA' and c.name='PNC Financial Services Group'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Various Professional Technical Administrative and Scientific positions supporting a Public Health Client' and l.name='Atlanta GA' and c.name='Alakaina Foundation Family of Companies'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Engineer II Packaging Research' and l.name='Atlanta GA 30301 ' and c.name='The CocaCola Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Pediatrics – Dir Pediatric Clinical and Translational Research' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Avionics System Designer  ELSYS' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Business Development Manager Southeast Region' and l.name='Atlanta GA' and c.name='Catapult Sports'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Research Analyst and Team Lead  HR Insights  Bersin' and l.name='Atlanta GA' and c.name='Deloitte'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Landscape Architect Graduate' and l.name='Atlanta GA 30309 ' and c.name='Jacobs'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Implementation Engineer Machine LearningData Analytics' and l.name='Atlanta GA 30326 ' and c.name='eHire LLC'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Sales Account Executive' and l.name='Atlanta GA' and c.name='Clear Story Data'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='PostDoctoral Fellowship Training Program in Cancer Epidemiology Prevention and Survivorship' and l.name='Atlanta GA' and c.name='AMERICAN CANCER SOCIETY'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Software Researcher  CIPHER' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Configuration ManagementQuality Assurance Manager ATAS' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Practice Technology Regional BIM Manager East Region' and l.name='Atlanta GA' and c.name='HKS Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Windows Programmer  Software Engineer ELSYS' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Cyber Security Systems Engineer' and l.name='Atlanta GA' and c.name='ICF'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Technical Product Manager – Secureworks – Austin TX Atlanta GA DC Metro or Remote' and l.name='Atlanta GA' and c.name='DELL'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Atlanta GA 30328' and c.name='Matrix Resources'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior FPGA Hardware Researcher  CIPHER' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Environmental Project Engineer  CCRFly Ash NPDES' and l.name='Atlanta GA' and c.name='Stantec'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Technical Lead Data EngineerArchitect' and l.name='Atlanta GA' and c.name='Beacon Hill Technologies'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='PostDoctoral Fellow Medical Imaging Machine Learning and CT Physics' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Avionics System Designer Advanced Degree  ELSYS' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Branch Head for FPGA Hardware Research and Development  CIPHER' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sr Staff Enterprise Application Engineer' and l.name='Atlanta GA 30319' and c.name='General Electric'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Commercial Construction Market Leader – Global Facilities' and l.name='Atlanta GA 30309 ' and c.name='Burns  McDonnell'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Firmware Engineer  ELSYS' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# ...
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sr Software Engineer  DOCSIS  Fixed Networks Gainspeed' and l.name='Sunnyvale CA 94086' and c.name='NOKIA'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Quality Engineer QA' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Systems Integration Engineer' and l.name='Sunnyvale CA' and c.name='Cepheid'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Clinical Research Associate' and l.name='Sunnyvale CA' and c.name='Pharmacyclics an Abbvie Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Software Engineer' and l.name='Sunnyvale CA' and c.name='Oath Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Paranoids Sr Software Dev Engineer' and l.name='Sunnyvale CA' and c.name='Oath Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Principal Software Engineer  Telemetry' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Software Engineer Backend' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sr Front End Developer  Media Brands and Products' and l.name='Sunnyvale CA' and c.name='Oath Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Front End Engineer' and l.name='Sunnyvale CA' and c.name='Petuum Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sr Software Dev Engineer' and l.name='Sunnyvale CA' and c.name='Oath Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Principal Software Dev Engineer' and l.name='Sunnyvale CA' and c.name='Oath Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Staff SalesforceJava Engineer' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sr Front End Engineer  Oath Monitoring Team' and l.name='Sunnyvale CA' and c.name='Oath Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Principal Technical Program Manager' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Software Engineer  Back End' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Designer User Experience' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Director of IT Infrastructure Security  Architecture' and l.name='Sunnyvale CA' and c.name='Pharmacyclics an Abbvie Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Principal Full Stack JavaScript Developer Front End' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Platform Software Engineer  Fixed Networks Gainspeed' and l.name='Sunnyvale CA 94086' and c.name='NOKIA'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Designer User Experience  Mobile' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Manager Sales Operations' and l.name='Sunnyvale CA' and c.name='Pharmacyclics an Abbvie Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='SeniorStaff Full Stack Engineer  Advertising Technologies' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Manager Cost Accounting' and l.name='Sunnyvale CA' and c.name='Pharmacyclics an Abbvie Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Security Scientist' and l.name='Sunnyvale CA 94089' and c.name='Baidu USA'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sr Data Scientist' and l.name='Sunnyvale CA' and c.name='Oath Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Applied Scientist' and l.name='Sunnyvale CA' and c.name='Lab126'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Research Scientist  IDL Robotics' and l.name='Sunnyvale CA 94089' and c.name='Baidu USA'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist  AIdriven Enterprise SaaS' and l.name='Sunnyvale CA 94086' and c.name='Clari'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist Growth Analytics' and l.name='Sunnyvale CA' and c.name='Oath Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Data Scientist' and l.name='Sunnyvale CA 94086' and c.name='Castlight Health'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Sunnyvale CA 94089' and c.name='Proofpoint'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Head of Data Science Google Cloud Revenue Acceleration' and l.name='Sunnyvale CA' and c.name='Google'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Lead Data Scientist  Machine Learning' and l.name='Sunnyvale CA' and c.name='TARGET'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Staff Data Scientist  Tech CA TECH12458' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Machine Learning Scientist' and l.name='Sunnyvale CA' and c.name='Amazoncom'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist Path Forward Returnship' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Sunnyvale CA' and c.name='Linc Global Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist  Alexa Language Technologies' and l.name='Sunnyvale CA' and c.name='Lab126'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Sunnyvale CA' and c.name='Oath Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Sunnyvale CA 94085' and c.name='Bosch Group'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist Cloud Revenue Acceleration Google Cloud' and l.name='Sunnyvale CA' and c.name='Google'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data  Applied Scientist' and l.name='Sunnyvale CA' and c.name='Microsoft'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist  Alexa Language Technologies' and l.name='Sunnyvale CA' and c.name='Amazoncom'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist  Data Analyst' and l.name='Sunnyvale CA' and c.name='Arosys'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist Customer Interests  Personalization' and l.name='Sunnyvale CA' and c.name='Lab126'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist Customer Interests  Personalization' and l.name='Sunnyvale CA' and c.name='Amazoncom'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Principal Data Scientist' and l.name='Sunnyvale CA' and c.name='Microsoft'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist Engineering Support Analytics Google Cloud' and l.name='Sunnyvale CA' and c.name='Google'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Applied Scientist' and l.name='Sunnyvale CA' and c.name='Amazoncom'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Staff Data Scientist' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Staff Data Scientist SearchOnline Grocery' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Machine Learning Specialist Trust and Safety' and l.name='Sunnyvale CA' and c.name='Google'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Research Scientist' and l.name='Sunnyvale CA' and c.name='Amazoncom'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Applied Machine Learning Scientist' and l.name='Sunnyvale CA' and c.name='Amazoncom'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Scientist' and l.name='Sunnyvale CA' and c.name='Microsoft'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Systems software Performance Data Scientist SunnyvaleChina' and l.name='Sunnyvale CA' and c.name='Alibaba'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Applied Scientist  Alexa Engine' and l.name='Sunnyvale CA' and c.name='Amazoncom'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Lead Data Scientist  NLP' and l.name='Sunnyvale CA' and c.name='TARGET'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Image processing Deep learning Research Scientist' and l.name='Sunnyvale CA 94085' and c.name='Whiterabbitai'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Machine Learning Scientist Amazon Alexa' and l.name='Sunnyvale CA' and c.name='Amazoncom'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Global Mobility Specialist Immigration' and l.name='Sunnyvale CA' and c.name='Google'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Engineer' and l.name='Sunnyvale CA' and c.name='Amazoncom'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Manager Machine Learning' and l.name='Sunnyvale CA' and c.name='Amazoncom'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Lead Data Scientist  Haskell' and l.name='Sunnyvale CA' and c.name='TARGET'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Data Scientist GEC11902' and l.name='Sunnyvale CA 94086' and c.name='Walmart'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Developer  Machine Learning Analyst' and l.name='Sunnyvale CA' and c.name='NetApp'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Scientist I' and l.name='Sunnyvale CA' and c.name='Pharmacyclics an Abbvie Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Intern Scientist' and l.name='Sunnyvale CA' and c.name='Oath Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Data  Applied Scientist' and l.name='Sunnyvale CA' and c.name='Microsoft'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Principal Data Scientist Deep Learning' and l.name='Sunnyvale CA 94089' and c.name='Comcast'
# <ipython-input-193-7947525a81d8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alldata_df["inserted"]=alldata_df.apply(lambda row: insert_for_alldata(row['Position'].translate(str.maketrans('', '', string.punctuation)), row['Location'].translate(str.maketrans('', '', string.punctuation)),row['Company'].translate(str.maketrans('', '', string.punctuation))) , axis =1)

# %%
for index, row in alldata_df.iterrows():
    insert_for_alldata(row['Position'].translate(str.maketrans('', '', string.punctuation)), row['Location'].translate(str.maketrans('', '', string.punctuation)),row['Company'].translate(str.maketrans('', '', string.punctuation)))
# Out:
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Development Director' and l.name='Atlanta GA 30301 ' and c.name='ALS TDI'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='An OstentatiouslyExcitable Principal Research Assistant to Chief Scientist' and l.name='Atlanta GA' and c.name='The Hexagon Lavish'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Atlanta GA' and c.name='Xpert Staffing'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Analyst' and l.name='Atlanta GA 30303 ' and c.name='Operation HOPE'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Assistant Professor TT  Signal Processing  Machine Learning' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Manager of Data Engineering' and l.name='Atlanta GA 30318 ' and c.name='McKinsey  Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Product Specialist  Periscope New Ventures' and l.name='Atlanta GA 30318 ' and c.name='McKinsey  Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Junior to Midlevel Engineer Geologist or Environmental Scientist' and l.name='Atlanta GA' and c.name='Wood'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Analyst  CIB Credit Research' and l.name='Atlanta GA' and c.name='SunTrust'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Associate  Cognitive Data Scientist Natural Language Processing' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='STATISTICAL FORECAST ANALYST' and l.name='Atlanta GA' and c.name='The Home Depot'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Health Scientist IIICPTS' and l.name='Atlanta GA' and c.name='Chenega Corporation'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Associate Data Scientist' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Assistant Scientist AR SOM' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Business Intelligence Data Science Analyst  Supply Chain' and l.name='Atlanta GA' and c.name='Newell Brands'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Atlanta GA' and c.name='Cotiviti'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Structural EngineerTransmission  Distribution' and l.name='Atlanta GA 30309 ' and c.name='Burns  McDonnell'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Mobile Developer iOSAndroid' and l.name='Atlanta GA 30338' and c.name='Perficient'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Atlanta GA' and c.name='Relus Cloud'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Atlanta GA' and c.name='Inspire Brands'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Electrical Engineer' and l.name='Atlanta GA 30309 ' and c.name='Burns  McDonnell'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sr Manager Full Stack Development KPMG Tax Ignition' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Atlanta GA 30309 ' and c.name='Norfolk Southern Corp'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='DATA SCIENTIST  Supply Chain' and l.name='Atlanta GA' and c.name='The Home Depot'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist Keying  Linking' and l.name='Atlanta GA' and c.name='Equifax'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Atlanta GA' and c.name='AirSage'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist 1 – AP Forensics Team' and l.name='Atlanta GA' and c.name='The Home Depot'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist  ICL' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist Online' and l.name='Atlanta GA' and c.name='The Home Depot'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist  CONSULTANT Level  ORLANDO FLORIDA  We will help Relocate' and l.name='Atlanta GA' and c.name='Capgemini'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Data Scientist' and l.name='Atlanta GA' and c.name='Catalina Marketing'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Business Intelligence Data Scientist  Supply Chain' and l.name='Atlanta GA' and c.name='Newell Brands'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Entry LevelJuniorLevel Scientist' and l.name='Atlanta GA' and c.name='Kleinfelder Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Scientist  Data Analysis' and l.name='Atlanta GA' and c.name='AMERICAN CANCER SOCIETY'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Atlanta GA' and c.name='SalesLoft'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Atlanta GA 30329' and c.name='McKesson'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Atlanta GA 30328' and c.name='The Intersect Group'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Health Scientist' and l.name='Atlanta GA' and c.name='Centers for Disease Control and Prevention'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Atlanta GA' and c.name='OM Partners'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='DATA SCIENTIST  SPACE OPTIMIZATION' and l.name='Atlanta GA' and c.name='The Home Depot'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Science Specialist  Periscope New Ventures' and l.name='Atlanta GA 30318 ' and c.name='McKinsey  Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Data Scientist' and l.name='Atlanta GA' and c.name='Cotiviti'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Manager  Data Scientist  Orlando' and l.name='Atlanta GA' and c.name='Capgemini'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Scientist II' and l.name='Atlanta GA 30301 ' and c.name='The CocaCola Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Lead Data Scientist' and l.name='Atlanta GA 30309 ' and c.name='Norfolk Southern Corp'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Data Scientist' and l.name='Atlanta GA 30309 ' and c.name='Norfolk Southern Corp'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist  Consultant Level  Orlando Florida  we will assist with relocation' and l.name='Atlanta GA' and c.name='Capgemini'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Flight Safety Data Analysis Fall CoOp' and l.name='Atlanta GA' and c.name='Delta Air Lines'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Chief Deep Learning Scientist' and l.name='Atlanta GA' and c.name='YIWEI Medical Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Supervisory Health Scientist' and l.name='Atlanta GA' and c.name='Centers for Disease Control and Prevention'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Manager  Cognitive Data Scientist Natural Language Processing' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Director Data Scientist' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='VP Data Scientist Atlanta GA Charlotte NC' and l.name='Atlanta GA' and c.name='Bank of America Merchant Services'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Statistical Analyst' and l.name='Atlanta GA' and c.name='Hawkins Diagnostics'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='VP Data Analytics' and l.name='Atlanta GA' and c.name='TCGplayer'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Lead Decision Scientist' and l.name='Atlanta GA 30313 ' and c.name='Moxie Interactive Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Scientist I  Sensory Panel Leader' and l.name='Atlanta GA 30301 ' and c.name='The CocaCola Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist or Data Scientist Lead PS10268' and l.name='Atlanta GA 30301 ' and c.name='Anthem Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Lead Decision Scientist' and l.name='Atlanta GA' and c.name='Moxie'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Cyber Security Data Scientist' and l.name='Atlanta GA 30306 ' and c.name='Bank of America'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Scientist IIEcologist II' and l.name='Atlanta GA 30327 ' and c.name='HNTB Corporation'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Engineer' and l.name='Atlanta GA' and c.name='Gallup'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Manager Data Scientist' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Machine Learning  Artificial Intelligence Research Scientist' and l.name='Atlanta GA 30338' and c.name='Symantec'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Statistical Quantitative Analyst' and l.name='Atlanta GA' and c.name='SunTrust'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Research Scientist' and l.name='Atlanta GA' and c.name='MacDermid Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Environmental Scientist' and l.name='Atlanta GA' and c.name='Tetra Tech'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Scientist Asst Bioinformatics' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Research Analyst' and l.name='Atlanta GA' and c.name='Evident'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Scientist Asst AR SOM' and l.name='Atlanta GA 30322' and c.name='Emory Healthcare'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Analyst Research' and l.name='Atlanta GA 30319' and c.name='Turner'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Director NLP Data Scientist' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Information Technology Specialist' and l.name='Atlanta GA' and c.name='Centers for Disease Control and Prevention'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Quantitative Analyst' and l.name='Atlanta GA 30342 ' and c.name='GreenSky'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='DATA ANALYST SUPPLY CHAIN' and l.name='Atlanta GA' and c.name='The Home Depot'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Scientist Asst AR SOM' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Health Communications Specialist' and l.name='Atlanta GA' and c.name='Eagle Medical Services'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Associate Data Scientist NLPAI' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Engineer  GC Insights New Ventures' and l.name='Atlanta GA 30318 ' and c.name='McKinsey  Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Technical Evangelist – Database Analytics and Machine Learning' and l.name='Atlanta GA' and c.name='Amazoncom'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sr Scientist II Analytical Science' and l.name='Atlanta GA 30301 ' and c.name='The CocaCola Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Director of Data Science' and l.name='Atlanta GA' and c.name='Prestige Staffing'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='HIV Research Scientist' and l.name='Atlanta GA' and c.name='Eagle Medical Services'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='SI CoE IoT Data Modeling Architect' and l.name='Atlanta GA' and c.name='Xylem'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Research Scientist' and l.name='Atlanta GA' and c.name='PreVisor'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Azure Data Scientist Manager' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Associate Scientist SOM' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Engineer Scala' and l.name='Atlanta GA' and c.name='CapTech Consulting'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Director Financial Services  Data Scientist' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Regulatory Labeling Advertising and Promotion Scientist' and l.name='Atlanta GA' and c.name='UCB'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data  Analytics Developer' and l.name='Atlanta GA' and c.name='SunTrust'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Product Development Scientist' and l.name='Atlanta GA 30301 ' and c.name='The CocaCola Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Research Scientist I' and l.name='Atlanta GA' and c.name='Georgia State University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist  Senior Consultant  Orlando Florida' and l.name='Atlanta GA' and c.name='Capgemini'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Lead R  D EngineerScientist' and l.name='Atlanta GA 30308 ' and c.name='Honeywell'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Quantitative Finance Analyst' and l.name='Atlanta GA 30308 ' and c.name='Bank of America'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Advertiser Research Analyst' and l.name='Atlanta GA' and c.name='Cox Media Group'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Manager Data Scientist MLNLP  Financial Services' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Science Instructor' and l.name='Atlanta GA' and c.name='General Assembly'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Research Informatics Analyst' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Enterprise Data Analyst  Data Engineer' and l.name='Atlanta GA' and c.name='Novelis'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Supply Chain Data Science Consultant' and l.name='Atlanta GA' and c.name='Accenture'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Public Health Communications Specialist' and l.name='Atlanta GA 30328' and c.name='2M Research Services'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Communications Specialist' and l.name='Atlanta GA 30318 ' and c.name='Loyal'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='2018  Health Research Analyst 2  New' and l.name='Atlanta GA 30301 ' and c.name='Northrop Grumman'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Business Intelligence Engineer' and l.name='Atlanta GA' and c.name='Amazoncom'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Staff Research Scientist VII Informational Interpretation Researcher' and l.name='Atlanta GA' and c.name='The Hexagon Lavish'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Scientist Asst AR School Of Medicine SOM' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Entry Level Geologist Engineer or Environmental Scientist' and l.name='Atlanta GA' and c.name='Wood'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Regulatory Labeling Advertising and Promotion Scientist' and l.name='Atlanta GA' and c.name='UCB SA'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Quantitative Analyst' and l.name='Atlanta GA 30327 ' and c.name='Voya Financial'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Director Data Scientist  Financial ServicesInsurance' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Supervisory Epidemiologist' and l.name='Atlanta GA' and c.name='Centers for Disease Control and Prevention'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Quantitative Finance AnalystC Developer' and l.name='Atlanta GA 30308 ' and c.name='Bank of America'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Jr Microbiologist  CDC' and l.name='Atlanta GA' and c.name='G2S Corporation'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Azure Data Scientist Senior Associate' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Research Analyst' and l.name='Atlanta GA' and c.name='Epiq Systems Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Coding Research Analyst' and l.name='Atlanta GA' and c.name='Zelis Healthcare'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Science Manager Atlanta' and l.name='Atlanta GA' and c.name='Capgemini'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Quantitative Analyst' and l.name='Atlanta GA' and c.name='Intercontinental Exchange'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Visualization Software Engineer' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Business Intelligence Analyst People Analytics  Measurement' and l.name='Atlanta GA 30318 ' and c.name='McKinsey  Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Mid Data Scientist  Machine Learning' and l.name='Atlanta GA 30342 ' and c.name='Elev8 Hire Solutions'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Vendor Research Analyst' and l.name='Atlanta GA' and c.name='Northside Hospital'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Big Data SW Engineer' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Scientist Content Science' and l.name='Atlanta GA' and c.name='Pandora Media Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sponsored Research Financial Analyst' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Supply Chain Data Science Manager' and l.name='Atlanta GA' and c.name='Accenture'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Director HR Data and Insights' and l.name='Atlanta GA' and c.name='WestRock'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='BI Quantitative Analyst' and l.name='Atlanta GA 30341' and c.name='Childrens Healthcare of Atlanta'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Research Specialist' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Associate Product Designer' and l.name='Atlanta GA 30319' and c.name='IBM'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Ecologist' and l.name='Atlanta GA 30326 ' and c.name='VHB'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Tech Fall 2018 Intern  Machine Learning' and l.name='Atlanta GA 30319' and c.name='Turner'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='RD Innovation Engineer  Video AnalyticsMachine Learning' and l.name='Atlanta GA 30308 ' and c.name='Honeywell'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Lead Data Engineer' and l.name='Atlanta GA 30361 ' and c.name='ThoughtWorks'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Analytics Engineer  Big Data Engineer' and l.name='Atlanta GA' and c.name='UST Global Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Corporate Investment Quantitative Finance Analyst' and l.name='Atlanta GA 30308 ' and c.name='Bank of America'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Malware Analyst' and l.name='Atlanta GA' and c.name='ICF'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Principal Research Scientist I Informational Library Architect Extraordinaire' and l.name='Atlanta GA' and c.name='The Hexagon Lavish'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Market Research Analyst' and l.name='Atlanta GA' and c.name='SKIM'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Manager Statistical Modeling  Analytics' and l.name='Atlanta GA 30363 ' and c.name='Piedmont Healthcare'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Scientist Advertising' and l.name='Atlanta GA' and c.name='Pandora Media Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Junior Specialist  Periscope Advanced Insights Growth Mapping New Ventures' and l.name='Atlanta GA 30318 ' and c.name='McKinsey  Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Full Stack Developer' and l.name='Atlanta GA 30342 ' and c.name='GreenSky'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Associate Data ScientistStatistics  Financial Services' and l.name='Atlanta GA 30338' and c.name='KPMG'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Assistant Scientist  Metabolics Division Lead' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Data Engineer Next Big Sound' and l.name='Atlanta GA' and c.name='Pandora Media Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Market Research Analyst' and l.name='Atlanta GA' and c.name='ResMed'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Biomedical Engineering Faculty Position  Open Rank Asst or Assoc Professor' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Solutions Consultant' and l.name='Atlanta GA' and c.name='Oversight Systems'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Scientist Immunology' and l.name='Atlanta GA' and c.name='GeoVax Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Director Data Science PS6695' and l.name='Atlanta GA 30301 ' and c.name='Anthem Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='A VigorouslyCharged Scientific Programmer' and l.name='Atlanta GA' and c.name='The Hexagon Lavish'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Software Engineer' and l.name='Atlanta GA' and c.name='FraudScope'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sr Data Scientist – Market Research' and l.name='Atlanta GA' and c.name='Analytic Recruiting'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Director of Software' and l.name='Atlanta GA 30332 ' and c.name='Bionic Sciences Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Certifying Scientist  Quantitation Scientist' and l.name='Atlanta GA' and c.name='Lighthouse Lab Services'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Data Scientist' and l.name='Atlanta GA' and c.name='Smith Hanley Associates'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sr Manager  Data  Analytics' and l.name='Atlanta GA 30319' and c.name='General Electric'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Big Data Engineer mid to senior level' and l.name='Atlanta GA 30342 ' and c.name='GreenSky'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Atlanta GA 30326 ' and c.name='Xpect SVC LLC'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Science  Senior Consultant' and l.name='Atlanta GA' and c.name='Capgemini'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Adolescent Health Evaluation Specialist' and l.name='Atlanta GA' and c.name='ICF'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Windows Programmer  Software Engineer  IntermediateSenior ELSYS 7332' and l.name='Atlanta GA' and c.name='The Goal Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sr Data Engineer' and l.name='Atlanta GA' and c.name='Optomi'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Team Lead – Informatics Sensus USA Inc Atlanta Georgia' and l.name='Atlanta GA' and c.name='Xylem'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Electrical  Substation Design Engineer' and l.name='Atlanta GA 30309 ' and c.name='Burns  McDonnell'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Windows Programmer  Software Engineer Advanced Degree  ELSYS' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='ElectricalComputer Engineer  EOSL' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Windows Programmer  Software Engineer  Entry Intermediate ELSYS  7333' and l.name='Atlanta GA' and c.name='The Goal Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Principal Research Scientist' and l.name='Atlanta GA' and c.name='Headway Workforce Solutions'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Business Intelligence Analyst' and l.name='Atlanta GA' and c.name='The Home Depot'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Software Engineer Machine Learning' and l.name='Atlanta GA' and c.name='Pandora Media Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Scientist' and l.name='Atlanta GA' and c.name='RD Partners'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Staff CAD Technician' and l.name='Atlanta GA 30341' and c.name='Golder Associates'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Engineering Coop' and l.name='Atlanta GA 30341' and c.name='Golder Associates'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Associate Manager Agile Paid Media' and l.name='Atlanta GA' and c.name='The Home Depot'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Category Manager' and l.name='Atlanta GA' and c.name='JUUL Labs'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='FPGA Hardware Researcher  CIPHER' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Marketing Research Analyst' and l.name='Atlanta GA 30309 ' and c.name='HD Supply'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='RightofWay Acquisition Manager  Atlanta GA' and l.name='Atlanta GA' and c.name='Gresham Smith and Partners'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Associate Research Scientist' and l.name='Atlanta GA' and c.name='RD Partners'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='EntryLevel Electrical Engineer' and l.name='Atlanta GA 30309 ' and c.name='Burns  McDonnell'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Staff Software Engineer' and l.name='Atlanta GA 30319' and c.name='General Electric'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Principal Engineer' and l.name='Atlanta GA' and c.name='Cotiviti'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='DevOps Engineer  ELSYS' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Analyst Payments Study  GC Insights New Ventures' and l.name='Atlanta GA 30318 ' and c.name='McKinsey  Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Analyst  Multiclient Benchmarks GC Insights  New Ventures' and l.name='Atlanta GA 30318 ' and c.name='McKinsey  Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='BI  Analytics  Cloud Platform Operations Analyst' and l.name='Atlanta GA 30301 ' and c.name='The CocaCola Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sr Quantitative Finance AnalystC Developer' and l.name='Atlanta GA 30308 ' and c.name='Bank of America'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Business Analytics Consultant Sr' and l.name='Atlanta GA' and c.name='PNC Financial Services Group'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Various Professional Technical Administrative and Scientific positions supporting a Public Health Client' and l.name='Atlanta GA' and c.name='Alakaina Foundation Family of Companies'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Engineer II Packaging Research' and l.name='Atlanta GA 30301 ' and c.name='The CocaCola Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Pediatrics – Dir Pediatric Clinical and Translational Research' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Avionics System Designer  ELSYS' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Business Development Manager Southeast Region' and l.name='Atlanta GA' and c.name='Catapult Sports'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Research Analyst and Team Lead  HR Insights  Bersin' and l.name='Atlanta GA' and c.name='Deloitte'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Landscape Architect Graduate' and l.name='Atlanta GA 30309 ' and c.name='Jacobs'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Implementation Engineer Machine LearningData Analytics' and l.name='Atlanta GA 30326 ' and c.name='eHire LLC'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Sales Account Executive' and l.name='Atlanta GA' and c.name='Clear Story Data'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='PostDoctoral Fellowship Training Program in Cancer Epidemiology Prevention and Survivorship' and l.name='Atlanta GA' and c.name='AMERICAN CANCER SOCIETY'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Software Researcher  CIPHER' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Configuration ManagementQuality Assurance Manager ATAS' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Practice Technology Regional BIM Manager East Region' and l.name='Atlanta GA' and c.name='HKS Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Windows Programmer  Software Engineer ELSYS' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Cyber Security Systems Engineer' and l.name='Atlanta GA' and c.name='ICF'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Technical Product Manager – Secureworks – Austin TX Atlanta GA DC Metro or Remote' and l.name='Atlanta GA' and c.name='DELL'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Atlanta GA 30328' and c.name='Matrix Resources'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior FPGA Hardware Researcher  CIPHER' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Environmental Project Engineer  CCRFly Ash NPDES' and l.name='Atlanta GA' and c.name='Stantec'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Technical Lead Data EngineerArchitect' and l.name='Atlanta GA' and c.name='Beacon Hill Technologies'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='PostDoctoral Fellow Medical Imaging Machine Learning and CT Physics' and l.name='Atlanta GA' and c.name='Emory University'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Avionics System Designer Advanced Degree  ELSYS' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Branch Head for FPGA Hardware Research and Development  CIPHER' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sr Staff Enterprise Application Engineer' and l.name='Atlanta GA 30319' and c.name='General Electric'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Commercial Construction Market Leader – Global Facilities' and l.name='Atlanta GA 30309 ' and c.name='Burns  McDonnell'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Firmware Engineer  ELSYS' and l.name='Atlanta GA 30318 ' and c.name='Georgia Tech Research Institute'
# ...
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior System Specialist LTE  Digital Automation' and l.name='Sunnyvale CA 94086' and c.name='NOKIA'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Software Engineer VUDU' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior IT Quality Engineer' and l.name='Sunnyvale CA' and c.name='Pharmacyclics an Abbvie Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sr Software Engineer  DOCSIS  Fixed Networks Gainspeed' and l.name='Sunnyvale CA 94086' and c.name='NOKIA'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Quality Engineer QA' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Systems Integration Engineer' and l.name='Sunnyvale CA' and c.name='Cepheid'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Clinical Research Associate' and l.name='Sunnyvale CA' and c.name='Pharmacyclics an Abbvie Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Software Engineer' and l.name='Sunnyvale CA' and c.name='Oath Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Paranoids Sr Software Dev Engineer' and l.name='Sunnyvale CA' and c.name='Oath Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Principal Software Engineer  Telemetry' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Software Engineer Backend' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sr Front End Developer  Media Brands and Products' and l.name='Sunnyvale CA' and c.name='Oath Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Front End Engineer' and l.name='Sunnyvale CA' and c.name='Petuum Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sr Software Dev Engineer' and l.name='Sunnyvale CA' and c.name='Oath Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Principal Software Dev Engineer' and l.name='Sunnyvale CA' and c.name='Oath Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Staff SalesforceJava Engineer' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sr Front End Engineer  Oath Monitoring Team' and l.name='Sunnyvale CA' and c.name='Oath Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Principal Technical Program Manager' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Software Engineer  Back End' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Designer User Experience' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Director of IT Infrastructure Security  Architecture' and l.name='Sunnyvale CA' and c.name='Pharmacyclics an Abbvie Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Principal Full Stack JavaScript Developer Front End' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Platform Software Engineer  Fixed Networks Gainspeed' and l.name='Sunnyvale CA 94086' and c.name='NOKIA'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Designer User Experience  Mobile' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Manager Sales Operations' and l.name='Sunnyvale CA' and c.name='Pharmacyclics an Abbvie Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='SeniorStaff Full Stack Engineer  Advertising Technologies' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Manager Cost Accounting' and l.name='Sunnyvale CA' and c.name='Pharmacyclics an Abbvie Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Security Scientist' and l.name='Sunnyvale CA 94089' and c.name='Baidu USA'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Sr Data Scientist' and l.name='Sunnyvale CA' and c.name='Oath Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Applied Scientist' and l.name='Sunnyvale CA' and c.name='Lab126'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Research Scientist  IDL Robotics' and l.name='Sunnyvale CA 94089' and c.name='Baidu USA'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist  AIdriven Enterprise SaaS' and l.name='Sunnyvale CA 94086' and c.name='Clari'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist Growth Analytics' and l.name='Sunnyvale CA' and c.name='Oath Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Data Scientist' and l.name='Sunnyvale CA 94086' and c.name='Castlight Health'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Sunnyvale CA 94089' and c.name='Proofpoint'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Head of Data Science Google Cloud Revenue Acceleration' and l.name='Sunnyvale CA' and c.name='Google'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Lead Data Scientist  Machine Learning' and l.name='Sunnyvale CA' and c.name='TARGET'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Staff Data Scientist  Tech CA TECH12458' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Machine Learning Scientist' and l.name='Sunnyvale CA' and c.name='Amazoncom'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist Path Forward Returnship' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Sunnyvale CA' and c.name='Linc Global Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist  Alexa Language Technologies' and l.name='Sunnyvale CA' and c.name='Lab126'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Sunnyvale CA' and c.name='Oath Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist' and l.name='Sunnyvale CA 94085' and c.name='Bosch Group'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist Cloud Revenue Acceleration Google Cloud' and l.name='Sunnyvale CA' and c.name='Google'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data  Applied Scientist' and l.name='Sunnyvale CA' and c.name='Microsoft'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist  Alexa Language Technologies' and l.name='Sunnyvale CA' and c.name='Amazoncom'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist  Data Analyst' and l.name='Sunnyvale CA' and c.name='Arosys'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist Customer Interests  Personalization' and l.name='Sunnyvale CA' and c.name='Lab126'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist Customer Interests  Personalization' and l.name='Sunnyvale CA' and c.name='Amazoncom'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Principal Data Scientist' and l.name='Sunnyvale CA' and c.name='Microsoft'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Scientist Engineering Support Analytics Google Cloud' and l.name='Sunnyvale CA' and c.name='Google'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Applied Scientist' and l.name='Sunnyvale CA' and c.name='Amazoncom'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Staff Data Scientist' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Staff Data Scientist SearchOnline Grocery' and l.name='Sunnyvale CA' and c.name='Walmart eCommerce'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Machine Learning Specialist Trust and Safety' and l.name='Sunnyvale CA' and c.name='Google'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Research Scientist' and l.name='Sunnyvale CA' and c.name='Amazoncom'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Applied Machine Learning Scientist' and l.name='Sunnyvale CA' and c.name='Amazoncom'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Scientist' and l.name='Sunnyvale CA' and c.name='Microsoft'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Systems software Performance Data Scientist SunnyvaleChina' and l.name='Sunnyvale CA' and c.name='Alibaba'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Applied Scientist  Alexa Engine' and l.name='Sunnyvale CA' and c.name='Amazoncom'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Lead Data Scientist  NLP' and l.name='Sunnyvale CA' and c.name='TARGET'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Image processing Deep learning Research Scientist' and l.name='Sunnyvale CA 94085' and c.name='Whiterabbitai'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Machine Learning Scientist Amazon Alexa' and l.name='Sunnyvale CA' and c.name='Amazoncom'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Global Mobility Specialist Immigration' and l.name='Sunnyvale CA' and c.name='Google'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Engineer' and l.name='Sunnyvale CA' and c.name='Amazoncom'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Manager Machine Learning' and l.name='Sunnyvale CA' and c.name='Amazoncom'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Lead Data Scientist  Haskell' and l.name='Sunnyvale CA' and c.name='TARGET'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Data Scientist GEC11902' and l.name='Sunnyvale CA 94086' and c.name='Walmart'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Data Developer  Machine Learning Analyst' and l.name='Sunnyvale CA' and c.name='NetApp'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Scientist I' and l.name='Sunnyvale CA' and c.name='Pharmacyclics an Abbvie Company'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Intern Scientist' and l.name='Sunnyvale CA' and c.name='Oath Inc'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Senior Data  Applied Scientist' and l.name='Sunnyvale CA' and c.name='Microsoft'
# insert into alldata(PositionID,CompanyID,LocationID) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name='Principal Data Scientist Deep Learning' and l.name='Sunnyvale CA 94089' and c.name='Comcast'

# %%
#Create a function to creat a sql for PositionID,companyID and LocationID
def insert_for_datascientist(pos_name,loc_name,comp_name,ind_name,salaryestimate,rating):
    sql='''insert into datascientist(PositionID,CompanyID,LocationID,IndustryID,) select p.ID,l.ID,c.ID from Position p,Location l, Company c where p.name=\''''+pos_name+'''\' and l.name=\''''+loc_name+'''\' and c.name=\''''+comp_name+'\''
    execute_sql_statement(sql)
    return "success"
